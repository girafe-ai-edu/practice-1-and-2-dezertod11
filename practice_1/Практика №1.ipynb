# %% [markdown]
# ## Практика №1
#
# Jupyter-ноутбук — интерактивная среда разработки с «живым» кодом. В ней показана визуализация работы. Если разработчик хочет посмотреть на график или формулу, он пишет нужную команду в соответствующей ячейке. Такой подход экономит время и помогает избежать ошибок.

# %% [markdown]
# ## Полезные особенности
#
# Полный список хоткеев — в разделе Help → Keyboard Shortcuts.
# Магические команды, которые работают в ipython, которые могут помочь вам запускать и анализировать данные в jupyter nootbook. Они добавляют специальную функциональность, которую нелегко достичь с помощью кода Python или интерфейса ноутбука Jupyter.
#
# Все команды доступны по ссылке %lsmagic

# %% [markdown]
# ### Работа с ячейками
# Код выполняется внутри ячеек,последовательно исходя из номера слева от ячейки.

# %%
pip install -U ipykernel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipykernel in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (1.8.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (8.28.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (24.1)
# Requirement already satisfied: psutil in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: colorama in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\malne\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
b=2
print('Вывод переменной b = ',b)
# Out:
# Вывод переменной b =  2

# %%
#Мы можем вывести переменные из ранее запущенных ячеек
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 #Мы можем вывести переменные из ранее запущенных ячеек
# ----> 2 print(a,b)
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1428, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1470, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1277, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1905, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2197, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2194             from_this_thread.append(frame_custom_thread_id)
#    2196     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2197         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2199 frames_list = None
#    2201 if keep_suspended:
#    2202     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2266, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2263                 queue.put(internal_cmd)
#    2264                 wait_timeout = TIMEOUT_FAST
# -> 2266         notify_event.wait(wait_timeout)
#    2267         notify_event.clear()
#    2269 finally:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1776.0_x64__qbz5n2kfra8p0\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1776.0_x64__qbz5n2kfra8p0\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Типы переменных

# %%
#Числа
a = 1
b = 2.3 
c = 1+2j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#Конвертация типов переменных
a_float = float(a)
type(a_float)
# Out:
# float

# %%
#Строки
string_a = 'Какая то строка' 
print(type(string_a))
# Out:
# <class 'str'>

# %%
#Булевые переменные
a = True
print(type(a))
print('Но a + a = ',a+a)
# Out:
# <class 'bool'>
# Но a + a =  2

# %%
#Cписки (list)
list_=[1,1,2.3,'str']
type(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #Cписки (list)
#       2 list_=[1,1,2.3,'str']
# ----> 3 type(l)
#
# NameError: name 'l' is not defined

# %%
#Множество (set)
set_={1,1,2.3,'str'}
type(set_)

# %%
#Кортежи (turpl)
turpl_=(1,1,2.3,'str')
type(turpl_)

# %% [markdown]
# ### Нюансы присваивания и работы (повышенная сложность)
# изменяемые типы Python, включающие списки, словари и множества. Скажем, присваивание по смещению в списке фактически
# изменяет сам списковый объект на месте, а не создает совершенно новый такой объект.

# %%
L1 = [2, 3, 4]
L2 = L1
L1[0] = 24
print(L1)

print('Но и что L2 выглядит',L2)

# %%
#Можно сделать так, но функция co делает "поверхностное" копирование
import copy 
L1 = [2, 3, 4]
L2 = copy.copy(L1)
L1[0] = 24
L2

# %%
#Модно сделать так
L1 = [2, 3, 4]
L2 = L1[:]
L1[0] = 24
L2

# %% [markdown]
# ### Задание №1
# Есть размеры ширина (a) и длина комнаты(b) и высота стен (c), вывести объём комнаты в м3 c плавающей точкой

# %%
a = 3
b = 4
c = 3

#Ваш код сдесь
print(float(a * b * c))
# Out:
# 36.0

# %% [markdown]
# ### Задание №2
# Есть список значений list_v, выведите список без дубликатов значения

# %%
list_v = [2,2,3,4,5,0,0]

#Ваш код сдесь
set_v = set(list_v)
print(list(set_v))
# Out:
# [0, 2, 3, 4, 5]
